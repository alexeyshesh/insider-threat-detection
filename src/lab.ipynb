# %%
from cert import get_cert_dataset_graph

# %%
g = get_cert_dataset_graph()

# %%
from cdlib import algorithms
# Out:
# Note: to be able to use all crisp methods, you need to install some additional packages:  {'bayanpy', 'infomap', 'graph_tool', 'wurlitzer'}
# Note: to be able to use all crisp methods, you need to install some additional packages:  {'ASLPAw', 'pyclustering'}
# Note: to be able to use all crisp methods, you need to install some additional packages:  {'infomap', 'wurlitzer'}

# %%
leiden_coms = algorithms.leiden(g)

# %%
import networkx as nx 
from cdlib import viz

pos = nx.spring_layout(g)
viz.plot_network_clusters(g, leiden_coms, pos, figsize=(5, 5))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/alexeyshesh/insider-threat-detection/src/lab.ipynb Cell 5 line 5
#       <a href='vscode-notebook-cell:/Users/alexeyshesh/insider-threat-detection/src/lab.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> from cdlib import viz
#       <a href='vscode-notebook-cell:/Users/alexeyshesh/insider-threat-detection/src/lab.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a> pos = nx.spring_layout(g)
# ----> <a href='vscode-notebook-cell:/Users/alexeyshesh/insider-threat-detection/src/lab.ipynb#W4sZmlsZQ%3D%3D?line=4'>5</a> viz.plot_network_clusters(g, leiden_coms, pos, figsize=(5, 5))
#
# File /usr/local/lib/python3.10/site-packages/cdlib/viz/networks.py:109, in plot_network_clusters(graph, partition, position, figsize, node_size, plot_overlaps, plot_labels, cmap, top_k, min_size)
#     106 plt.axis("off")
# ...

# %%
len(leiden_coms.communities)
# Out:
# 8

# %%
viz.plot_community_graph(g, leiden_coms, figsize=(3, 3))

# %%
import pandas as pd 

df = pd.read_csv('../data/r3.2/http.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /Users/alexeyshesh/insider-threat-detection/src/lab.ipynb Cell 8 line 3
#       <a href='vscode-notebook-cell:/Users/alexeyshesh/insider-threat-detection/src/lab.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> import pandas as pd
# ----> <a href='vscode-notebook-cell:/Users/alexeyshesh/insider-threat-detection/src/lab.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a> df = pd.read_csv('../data/r3.2/http.csv')
#
# ...

# %%
df.head()

# %%
dfx = df[df.apply(lambda x: 'jobs' in x[''] ,axis=1)]
